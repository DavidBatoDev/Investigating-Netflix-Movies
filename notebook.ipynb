# %% [markdown]
# <center><img src="redpopcorn.jpg"></center>

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry.
#
# You work for a production company that specializes in nostalgic styles. You want to do some research on movies released in the 1990's. You'll delve into Netflix data and perform exploratory data analysis to better understand this awesome movie decade!
#
# You have been supplied with the dataset `netflix_data.csv`, along with the following table detailing the column names and descriptions. Feel free to experiment further after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")

# %% [markdown]
# ### To gather what the data really is and what is the column for each row we can loop through the DataFrame

# %%
# list of columns
for col in netflix_df:
    print(col)
# Out:
# show_id
# type
# title
# director
# cast
# country
# date_added
# release_year
# duration
# description
# genre

# %% [markdown]
# Start by filtering movies released in 1990
# ### We can use methods like loc or iloc

# %%
all_shows_in_1990s = netflix_df.loc[(netflix_df['release_year'] >= 1990) & (netflix_df['release_year'] <= 1999)]
movies_in_1990s = all_shows_in_1990s.loc[all_shows_in_1990s['type'] == 'Movie']
movies_in_1990s.head(5)
# Out:
#     show_id   type                            title            director  \
# 6        s8  Movie                              187      Kevin Reynolds
# 118    s167  Movie                A Dangerous Woman  Stephen Gyllenhaal
# 145    s211  Movie           A Night at the Roxbury    John Fortenberry
# 167    s239  Movie  A Thin Line Between Love & Hate     Martin Lawrence
# 194    s274  Movie                     Aashik Awara         Umesh Mehra
#
#                                                   cast        country  \
# 6    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 118  Debra Winger, Barbara Hershey, Gabriel Byrne, ...  United States
# 145  Will Ferrell, Chris Kattan, Dan Hedaya, Molly ...  United States
# 167  Martin Lawrence, Lynn Whitfield, Regina King, ...  United States
# 194  Saif Ali Khan, Mamta Kulkarni, Mohnish Bahl, S...          India
#
#            date_added  release_year  duration  \
# 6    November 1, 2019          1997       119
# ...

# %% [markdown]
# ## Now that we got the movies that was released in 1990s we can now then performs the task give

# %% [markdown]
# # Task 1: get the most frequent movie duration in the 1990s

# %%
# Get all duration column values of movies in 1990s
movies_duration_in_1990s = movies_in_1990s["duration"]
# Graph it in histogram to see the distribution
plt.hist(movies_duration_in_1990s, edgecolor='black')

# Add labels and title
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Durations in 1990')

# Get the most frequent movie duration in 1990s
duration = movies_duration_in_1990s.mode()[0]
print(f'The most frequent movie duration in 1990s is {duration}')
# Out:
# 94 minutes

# %% [markdown]
# ### - The Most frequent Movie Duration is approxiamtely 94 minutes
